# %%
import sys
import os

# %%
project_dir = os.path.dirname(os.getcwd())

# %%
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("classifier.ipynb"), "..")))

# %% [markdown]
# ## Import the Classes

# %%
from models.decisiontreeregressor import DecisionTreeRegressor
from models.randomforestregressor import RandomForestRegressor
from models.xgboostregressor import XGBoostRegressor
from models.linearregression import LinearRegression
from models.linearregression_closed import LinearRegressionClosed

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the data

# %%
insurance = pd.read_csv(os.path.join(project_dir, "data/insurance.csv"))

# %%
X = insurance.drop(columns="target")
y = insurance["target"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 X = insurance.drop(columns="target")
#       2 y = insurance["target"]
#
# File ~/Documents/from-scratch/.venv/lib/python3.13/site-packages/pandas/core/frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~/Documents/from-scratch/.venv/lib/python3.13/site-packages/pandas/core/generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# -> 4632                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4633
#    4634         if inplace:
#    4635             self._update_inplace(obj)
#
# File ~/Documents/from-scratch/.venv/lib/python3.13/site-packages/pandas/core/generic.py:4674, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4670                 if not isinstance(axis, MultiIndex):
#    4671                     raise AssertionError("axis must be a MultiIndex")
#    4672                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4673             else:
# -> 4674                 new_axis = axis.drop(labels, errors=errors)
#    4675             indexer = axis.get_indexer(new_axis)
#    4676
#    4677         # Case for non-unique axis
#
# File ~/Documents/from-scratch/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['target'] not found in axis"

# %%
n = len(X)

# %%
indices = np.arange(n)
np.random.shuffle(indices)

# %%
s1 = int(0.75 * n)

# %%
X_train = X.iloc[indices[:s1],]
y_train = y.iloc[indices[:s1],]
X_test = X.iloc[indices[s1:],]
y_test = y.iloc[indices[s1:],]

# %% [markdown]
# ## Logistic Regression

# %%
lg = LogisticRegression()

# %%
lg.fit(X_train, y_train)
# Out:
# /Users/vallurileelasaikrishna/Documents/from-scratch/models/logisticregression.py:16: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-z))

# %%
lg.accuracy(X_test, y_test)
# Out:
# /Users/vallurileelasaikrishna/Documents/from-scratch/.venv/lib/python3.13/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# np.float64(0.5758754863813229)

# %% [markdown]
# ## Decision Tree

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train, y_train)

# %%
dtc.accuracy_test(X_test, y_test)
# Out:
# np.float64(0.8871595330739299)

# %% [markdown]
# ## Random Forest

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)

# %%
rfc.accuaracy_test(X_test, y_test)
# Out:
# np.float64(0.9260700389105059)

# %% [markdown]
# ## XGBoost

# %%
xgbc = XGBoostClassifier()

# %% [markdown]
# xgb takes train and val at the same time for fit

# %%
s1 = int(0.7 * n)
s2 = int(0.85 * n)

# %%
X_train = X.iloc[indices[:s1],]
y_train = y.iloc[indices[:s1],]
X_val = X.iloc[indices[s1:s2],]
y_val = y.iloc[indices[s1:s2],]
X_test = X.iloc[indices[s2:],]
y_test = y.iloc[indices[s2:],]

# %%
xgbc.fit(X_train, y_train, X_val, y_val)
# Out:
# Early stopping at tree 584

# %%
xgbc.accuracy(X_test, y_test)
# Out:
# np.float64(0.9514563106796117)

# %% [markdown]
# ### Model Performance Comparison
#
# | Model | Accuracy |
# |--------|----------:|
# | Logistic Regression | **0.5759** (57.59%) |
# | Decision Tree | **0.8872** (88.72%) |
# | Random Forest | **0.9261** (92.61%) |
# | XGBoost | **0.9515** (95.15%) |
